# %%
from fastai.vision.all import *

# %%
im = PILImage.create('data/single/bird.jpg')
im.thumbnail((192,192))
im
# Out:
# PILImage mode=RGB size=192x188

# %%
# !pwd
# Out:
# /Users/demon_slayer/Documents/GitHub/fast.ai-course/class/Lesson 1 - Is it a bird?

# %%
# !ls
# Out:
# 00-is-it-a-bird-creating-a-model-from-your-own-data.ipynb
# 00-is-it-a-bird-creating-a-model-from-your-own-data.py
# RunModel.ipynb
# data
# models
# resnet18.pkl

# %%
learn = load_learner('resnet18.pkl')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 learn = load_learner('resnet18.pkl')
#
# File ~/.pyenv/versions/mambaforge/lib/python3.10/site-packages/fastai/learner.py:428, in load_learner(fname, cpu, pickle_module)
#     426 distrib_barrier()
#     427 map_loc = 'cpu' if cpu else default_device()
# --> 428 try: res = torch.load(fname, map_location=map_loc, pickle_module=pickle_module)
#     429 except AttributeError as e:
#     430     e.args = [f"Custom classes or functions exported with your `Learner` not available in namespace.\Re-declare/import before loading:\n\t{e.args[0]}"]
#
# File ~/.pyenv/versions/mambaforge/lib/python3.10/site-packages/torch/serialization.py:712, in load(f, map_location, pickle_module, **pickle_load_args)
#     710             opened_file.seek(orig_position)
# ...

# %%
prediction, idx, probability = learn.predict(im)
prediction
